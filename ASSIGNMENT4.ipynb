# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyndz456/AI-Coursework-2025/blob/main/ASSIGNMENT4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-261bceb5-63a2-4c67-8862-46fee837c5f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-261bceb5-63a2-4c67-8862-46fee837c5f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.tail(20)['type'].value_counts()
# Out:
# type
# Movie      15
# TV Show     5
# Name: count, dtype: int64

# %%
df.tail(20)
# Out:
#      show_id     type                          title                 director  \
# 8787   s8788    Movie      You Can’t Fight Christmas              Kenny Young
# 8788   s8789    Movie                   You Carry Me               Ivona Juka
# 8789   s8790    Movie            You Changed My Life      Cathy Garcia-Molina
# 8790   s8791    Movie  You Don't Mess with the Zohan             Dennis Dugan
# 8791   s8792    Movie                    Young Adult            Jason Reitman
# 8792   s8793    Movie                    Young Tiger                   Mu Chu
# 8793   s8794    Movie           Yours, Mine and Ours             Raja Gosnell
# 8794   s8795    Movie                         اشتباك             Mohamed Diab
# 8795   s8796  TV Show                Yu-Gi-Oh! Arc-V                      NaN
# 8796   s8797  TV Show                     Yunus Emre                      NaN
# 8797   s8798  TV Show                      Zak Storm                      NaN
# ...

# %% [markdown]
#  Give the number of all Movies originating from South Africa:

# %%
df[df['country'] == 'South Africa'].shape[0]
# Out:
# 30

# %% [markdown]
# Give the number of all Movies originating from South Africa: 30

# %%
df.loc[11, 'description']
# Out:
# 'Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.'

# %% [markdown]
# Description for the movie in the 12th row: Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.

# %%
df[(df['country'] == 'South Africa') & (df['release_year'] == 2021)]
# Out:
#      show_id     type                         title       director  \
# 1         s2  TV Show                 Blood & Water            NaN
# 293     s294    Movie                          Slay      Adze Ugah
# 764     s765    Movie  Trippin' with the Kandasamys  Jayan Moodley
# 881     s882    Movie                I Am All Girls  Donovan Marsh
# 1172   s1173    Movie       Loyiso Gola: Unlearning  Kagiso Lediga
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 293   Enhle Mbali, Ramsey Nouah, Dawn Thandeka Kang,...  South Africa
# 764   Jailoshini Naidoo, Maeshni Naicker, Madhushan ...  South Africa
# 881   Erica Wessels, Hlubi Mboya, Deon Lotz, Brendon...  South Africa
# 1172                                        Loyiso Gola  South Africa
#
#               date_added  release_year rating   duration  \
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Movies made in South Africa released in 2021: (In Code cell)

# %%
df[df['release_year'] == 2021]['cast']
# Out:
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5       Kate Siegel, Zach Gilford, Hamish Linklater, H...
#                               ...
# 1468             Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# 1551    Bella Ramsey, Ameerah Falzon-Ojo, Oliver Nelso...
# 1696    Emily Tennant, Shannon Chan-Kent, Kazumi Evans...
# 2920                          Nick Lachey, Vanessa Lachey
# 8437         David Spade, London Hughes, Fortune Feimster
# Name: cast, Length: 592, dtype: object

# %% [markdown]
# Entire cast of movie of all movies released in 2021( In code cell output)
